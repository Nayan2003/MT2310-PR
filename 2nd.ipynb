# %% [markdown]
# #Assignment-2

# %% [markdown]
# ##Anjali vishwakarma-MT2310

# %%
pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#import python Libaries
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\nano\Downloads\StudentPerformanceFactors.csv", encoding='ISO-8859-1')

# %%
# (r"C:\Users\nano\Downloads\StudentPerformanceFactors.csv", encoding='ISO-8859-1')

# %%
df.columns.values
# Out:
# array(['Hours_Studied', 'Attendance', 'Parental_Involvement',
#        'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours',
#        'Previous_Scores', 'Motivation_Level', 'Internet_Access',
#        'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality',
#        'School_Type', 'Peer_Influence', 'Physical_Activity',
#        'Learning_Disabilities', 'Parental_Education_Level',
#        'Distance_from_Home', 'Gender', 'Exam_Score'], dtype=object)

# %%
df.dtypes
# Out:
# Hours_Studied                  int64
# Attendance                     int64
# Parental_Involvement          object
# Access_to_Resources           object
# Extracurricular_Activities    object
# Sleep_Hours                    int64
# Previous_Scores                int64
# Motivation_Level              object
# Internet_Access               object
# Tutoring_Sessions              int64
# Family_Income                 object
# Teacher_Quality               object
# School_Type                   object
# Peer_Influence                object
# Physical_Activity              int64
# Learning_Disabilities         object
# Parental_Education_Level      object
# Distance_from_Home            object
# Gender                        object
# Exam_Score                     int64
# dtype: object

# %%
df.shape
# Out:
# (6607, 20)

# %%
df.shape[0]
# Out:
# 6607

# %%
df.shape[1]
# Out:
# 20

# %%
df.head(5)
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df.tail(5)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 6602                         No            7               76
# 6603                         No            8               81
# 6604                        Yes            6               65
# 6605                        Yes            6               91
# 6606                        Yes            9               94
#
#      Motivation_Level Internet_Access  Tutoring_Sessions Family_Income  \
# 6602           Medium             Yes                  1          High
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
df.Attendance.count()
# Out:
# np.int64(6607)

# %%
df.Attendance.value_counts()
# Out:
# Attendance
# 67     190
# 98     187
# 76     185
# 77     184
# 64     182
# 94     180
# 91     175
# 84     175
# 79     175
# 82     173
# 69     170
# 68     170
# 80     169
# 96     168
# 73     168
# 81     168
# 93     167
# 72     167
# 74     165
# 78     165
# 61     164
# 95     163
# 71     162
# 89     162
# 97     161
# 70     161
# 65     158
# 83     157
# 90     156
# 63     155
# 88     155
# 92     154
# 99     154
# 62     152
# 87     151
# 86     151
# 75     149
# 85     146
# 66     145
# 60      87
# 100     81
# Name: count, dtype: int64

# %%
df.isnull()
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0             False       False                 False                False
# 1             False       False                 False                False
# 2             False       False                 False                False
# 3             False       False                 False                False
# 4             False       False                 False                False
# ...             ...         ...                   ...                  ...
# 6602          False       False                 False                False
# 6603          False       False                 False                False
# 6604          False       False                 False                False
# 6605          False       False                 False                False
# 6606          False       False                 False                False
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df.notnull()
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0              True        True                  True                 True
# 1              True        True                  True                 True
# 2              True        True                  True                 True
# 3              True        True                  True                 True
# 4              True        True                  True                 True
# ...             ...         ...                   ...                  ...
# 6602           True        True                  True                 True
# 6603           True        True                  True                 True
# 6604           True        True                  True                 True
# 6605           True        True                  True                 True
# 6606           True        True                  True                 True
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df[df.notnull()]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df[df.isnull()]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0               NaN         NaN                  NaN                 NaN
# 1               NaN         NaN                  NaN                 NaN
# 2               NaN         NaN                  NaN                 NaN
# 3               NaN         NaN                  NaN                 NaN
# 4               NaN         NaN                  NaN                 NaN
# ...             ...         ...                  ...                 ...
# 6602            NaN         NaN                  NaN                 NaN
# 6603            NaN         NaN                  NaN                 NaN
# 6604            NaN         NaN                  NaN                 NaN
# 6605            NaN         NaN                  NaN                 NaN
# 6606            NaN         NaN                  NaN                 NaN
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
df.sum(numeric_only=True)
# Out:
# Hours_Studied        131977
# Attendance           528411
# Sleep_Hours           46441
# Previous_Scores      495991
# Tutoring_Sessions      9869
# Physical_Activity     19607
# Exam_Score           444226
# dtype: int64

# %%
df.mean(numeric_only=True)
# Out:
# Hours_Studied        19.975329
# Attendance           79.977448
# Sleep_Hours           7.029060
# Previous_Scores      75.070531
# Tutoring_Sessions     1.493719
# Physical_Activity     2.967610
# Exam_Score           67.235659
# dtype: float64

# %%
df.corr(numeric_only=True)
# Out:
#                    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# Hours_Studied           1.000000   -0.009908     0.010977         0.024846
# Attendance             -0.009908    1.000000    -0.015918        -0.020186
# Sleep_Hours             0.010977   -0.015918     1.000000        -0.021750
# Previous_Scores         0.024846   -0.020186    -0.021750         1.000000
# Tutoring_Sessions      -0.014282    0.014324    -0.012216        -0.013122
# Physical_Activity       0.004624   -0.022435    -0.000378        -0.011274
# Exam_Score              0.445455    0.581072    -0.017022         0.175079
#
#                    Tutoring_Sessions  Physical_Activity  Exam_Score
# Hours_Studied              -0.014282           0.004624    0.445455
# Attendance                  0.014324          -0.022435    0.581072
# Sleep_Hours                -0.012216          -0.000378   -0.017022
# Previous_Scores            -0.013122          -0.011274    0.175079
# ...

# %%
df.cov(numeric_only=True)
# Out:
#                    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# Hours_Studied          35.887221   -0.685388     0.096539         2.143278
# Attendance             -0.685388  133.344178    -0.269856        -3.356568
# Sleep_Hours             0.096539   -0.269856     2.155377        -0.459816
# Previous_Scores         2.143278   -3.356568    -0.459816       207.353789
# Tutoring_Sessions      -0.105287    0.203537    -0.022070        -0.232527
# Physical_Activity       0.028568   -0.267155    -0.000572        -0.167409
# Exam_Score             10.381837   26.104619    -0.097222         9.808232
#
#                    Tutoring_Sessions  Physical_Activity  Exam_Score
# Hours_Studied              -0.105287           0.028568   10.381837
# Attendance                  0.203537          -0.267155   26.104619
# Sleep_Hours                -0.022070          -0.000572   -0.097222
# Previous_Scores            -0.232527          -0.167409    9.808232
# ...

# %%
df.Sleep_Hours.mean()
# Out:
# np.float64(7.029060087785682)

# %%
df.Exam_Score.sum()
# Out:
# np.int64(444226)

# %%
df.fillna(0)
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df.isnull()
# Out:
#       Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0             False       False                 False                False
# 1             False       False                 False                False
# 2             False       False                 False                False
# 3             False       False                 False                False
# 4             False       False                 False                False
# ...             ...         ...                   ...                  ...
# 6602          False       False                 False                False
# 6603          False       False                 False                False
# 6604          False       False                 False                False
# 6605          False       False                 False                False
# 6606          False       False                 False                False
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
df[df.isnull()]
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0               NaN         NaN                  NaN                 NaN
# 1               NaN         NaN                  NaN                 NaN
# 2               NaN         NaN                  NaN                 NaN
# 3               NaN         NaN                  NaN                 NaN
# 4               NaN         NaN                  NaN                 NaN
# ...             ...         ...                  ...                 ...
# 6602            NaN         NaN                  NaN                 NaN
# 6603            NaN         NaN                  NaN                 NaN
# 6604            NaN         NaN                  NaN                 NaN
# 6605            NaN         NaN                  NaN                 NaN
# 6606            NaN         NaN                  NaN                 NaN
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df1=df.drop(['Tutoring_Sessions'],axis=1)
df1
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
df1.drop(['Parental_Involvement','Motivation_Level'],axis=1)
# Out:
#       Hours_Studied  Attendance Access_to_Resources  \
# 0                23          84                High
# 1                19          64              Medium
# 2                24          98              Medium
# 3                29          89              Medium
# 4                19          92              Medium
# ...             ...         ...                 ...
# 6602             25          69              Medium
# 6603             23          76              Medium
# 6604             20          90                 Low
# 6605             10          86                High
# 6606             15          67                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores Internet_Access  \
# 0                            No            7               73             Yes
# 1                            No            8               59             Yes
# 2                           Yes            7               91             Yes
# ...

# %%
del df['Previous_Scores']

# %%
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours Motivation_Level Internet_Access  \
# ...

# %%
df.T
# Out:
#                                    0         1             2            3     \
# Hours_Studied                        23        19            24           29
# Attendance                           84        64            98           89
# Parental_Involvement                Low       Low        Medium          Low
# Access_to_Resources                High    Medium        Medium       Medium
# Extracurricular_Activities           No        No           Yes          Yes
# Sleep_Hours                           7         8             7            8
# Motivation_Level                    Low       Low        Medium       Medium
# Internet_Access                     Yes       Yes           Yes          Yes
# Tutoring_Sessions                     0         2             2            1
# Family_Income                       Low    Medium        Medium       Medium
# Teacher_Quality                  Medium    Medium        Medium       Medium
# ...

# %%
df.transpose()
# Out:
#                                    0         1             2            3     \
# Hours_Studied                        23        19            24           29
# Attendance                           84        64            98           89
# Parental_Involvement                Low       Low        Medium          Low
# Access_to_Resources                High    Medium        Medium       Medium
# Extracurricular_Activities           No        No           Yes          Yes
# Sleep_Hours                           7         8             7            8
# Motivation_Level                    Low       Low        Medium       Medium
# Internet_Access                     Yes       Yes           Yes          Yes
# Tutoring_Sessions                     0         2             2            1
# Family_Income                       Low    Medium        Medium       Medium
# Teacher_Quality                  Medium    Medium        Medium       Medium
# ...

# %%
df['new']=12
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours Motivation_Level Internet_Access  \
# ...

# %%
df['new_column_added_with85'] = 85
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours Motivation_Level Internet_Access  \
# ...
