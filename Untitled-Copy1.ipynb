# %% [markdown]
# #Assignment-1

# %% [markdown]
# ##Anjali vishwakarma-MT2310

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#import python Libaries
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\nano\OneDrive\Desktop\train.csv", encoding='ISO-8859-1')

# %%
# r"C:\Users\nano\OneDrive\Desktop\train.csv", encoding='ISO-8859-1'

# %%
df.columns.values
# Out:
# array(['Station', 'Station Code', 'Line',
#        'Distance From Previous of the Line',
#        'Time taken From Previous of the Line', 'About', 'Platforms',
#        'Tracks', 'Year of Opening ', 'Nearby attractions',
#        'Number of Passengers ', 'Previous names'], dtype=object)

# %%
df.dtypes
# Out:
# Station                                  object
# Station Code                             object
# Line                                     object
# Distance From Previous of the Line       object
# Time taken From Previous of the Line     object
# About                                    object
# Platforms                               float64
# Tracks                                  float64
# Year of Opening                         float64
# Nearby attractions                       object
# Number of Passengers                     object
# Previous names                           object
# dtype: object

# %%
df.shape
# Out:
# (202, 12)

# %%
df.shape[0]
# Out:
# 202

# %%
df.shape[1]
# Out:
# 12

# %%
df.head(5)
# Out:
#           Station Station Code     Line Distance From Previous of the Line  \
# 0      Churchgate          CCG  Western                               0 KM
# 1    Marine Lines          MEL  Western                               1 KM
# 2     Charni Road          CYR  Western                               1 KM
# 3      Grant Road          GTR  Western                               1 KM
# 4  Mumbai Central         MMCT  Western                               1 KM
#
#   Time taken From Previous of the Line  \
# 0                                0 min
# 1                                3 min
# 2                                2 min
# 3                                3 min
# 4                                2 min
#
#                                                About  Platforms  Tracks  \
# 0  The Fort area built by the British had three m...        4.0     4.0
# 1  Marine Lines (station code: MEL) is a railway ...        4.0     4.0
# ...

# %%
df.tail(5)
# Out:
#         Station Station Code            Line  \
# 197       Neral          NRL  Neral-Matheran
# 198   Jumapatti          JTT  Neral-Matheran
# 199   Waterpipe          WTP  Neral-Matheran
# 200  Aman Lodge         AMNA  Neral-Matheran
# 201    Matheran          MAE  Neral-Matheran
#
#     Distance From Previous of the Line Time taken From Previous of the Line  \
# 197                               0 KM                                0 min
# 198                               5 KM                               46 min
# 199                               6 KM                               46 min
# 200                               7 KM                               50 min
# 201                               2 KM                               18 min
#
#                                                  About  Platforms  Tracks  \
# 197  Neral Junction is a railway station on the Cen...        2.0     2.0
# 198  Jummapatti railway station is a railway statio...        NaN     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Station                               202 non-null    object
#  1   Station Code                          202 non-null    object
#  2   Line                                  202 non-null    object
#  3   Distance From Previous of the Line    202 non-null    object
#  4   Time taken From Previous of the Line  202 non-null    object
#  5   About                                 202 non-null    object
#  6   Platforms                             197 non-null    float64
#  7   Tracks                                193 non-null    float64
#  8   Year of Opening                       83 non-null     float64
#  9   Nearby attractions                    202 non-null    object
#  10  Number of Passengers                  21 non-null     object
# ...

# %%
df.Platforms.count()
# Out:
# np.int64(197)

# %%
df.Platforms.value_counts()
# Out:
# Platforms
# 2.0     70
# 4.0     49
# 3.0     27
# 8.0     12
# 6.0     11
# 7.0      9
# 1.0      5
# 5.0      5
# 10.0     4
# 15.0     3
# 9.0      2
# Name: count, dtype: int64

# %%
df.isnull()
# Out:
#      Station  Station Code   Line  Distance From Previous of the Line  \
# 0      False         False  False                               False
# 1      False         False  False                               False
# 2      False         False  False                               False
# 3      False         False  False                               False
# 4      False         False  False                               False
# ..       ...           ...    ...                                 ...
# 197    False         False  False                               False
# 198    False         False  False                               False
# 199    False         False  False                               False
# 200    False         False  False                               False
# 201    False         False  False                               False
#
#      Time taken From Previous of the Line  About  Platforms  Tracks  \
# ...

# %%
df.notnull()
# Out:
#      Station  Station Code  Line  Distance From Previous of the Line  \
# 0       True          True  True                                True
# 1       True          True  True                                True
# 2       True          True  True                                True
# 3       True          True  True                                True
# 4       True          True  True                                True
# ..       ...           ...   ...                                 ...
# 197     True          True  True                                True
# 198     True          True  True                                True
# 199     True          True  True                                True
# 200     True          True  True                                True
# 201     True          True  True                                True
#
#      Time taken From Previous of the Line  About  Platforms  Tracks  \
# 0                                    True   True       True    True
# ...

# %%
df[df.notnull()]
# Out:
#             Station Station Code            Line  \
# 0        Churchgate          CCG         Western
# 1      Marine Lines          MEL         Western
# 2       Charni Road          CYR         Western
# 3        Grant Road          GTR         Western
# 4    Mumbai Central         MMCT         Western
# ..              ...          ...             ...
# 197           Neral          NRL  Neral-Matheran
# 198       Jumapatti          JTT  Neral-Matheran
# 199       Waterpipe          WTP  Neral-Matheran
# 200      Aman Lodge         AMNA  Neral-Matheran
# 201        Matheran          MAE  Neral-Matheran
#
#     Distance From Previous of the Line Time taken From Previous of the Line  \
# 0                                 0 KM                                0 min
# 1                                 1 KM                                3 min
# 2                                 1 KM                                2 min
# ...

# %%
df[df.isnull()]
# Out:
#     Station Station Code Line Distance From Previous of the Line  \
# 0       NaN          NaN  NaN                                NaN
# 1       NaN          NaN  NaN                                NaN
# 2       NaN          NaN  NaN                                NaN
# 3       NaN          NaN  NaN                                NaN
# 4       NaN          NaN  NaN                                NaN
# ..      ...          ...  ...                                ...
# 197     NaN          NaN  NaN                                NaN
# 198     NaN          NaN  NaN                                NaN
# 199     NaN          NaN  NaN                                NaN
# 200     NaN          NaN  NaN                                NaN
# 201     NaN          NaN  NaN                                NaN
#
#     Time taken From Previous of the Line About  Platforms  Tracks  \
# 0                                    NaN   NaN        NaN     NaN
# ...

# %%
df.describe()
# Out:
#         Platforms      Tracks  Year of Opening
# count  197.000000  193.000000         83.000000
# mean     3.934010    4.792746       1914.542169
# std      2.505242    2.717334         52.801354
# min      1.000000    1.000000       1853.000000
# 25%      2.000000    3.000000       1867.500000
# 50%      3.000000    4.000000       1893.000000
# 75%      4.000000    6.000000       1966.000000
# max     15.000000   13.000000       2018.000000

# %%
df.sum(numeric_only=True)
# Out:
# Platforms              775.0
# Tracks                 925.0
# Year of Opening     158907.0
# dtype: float64

# %%
df.mean(numeric_only=True)
# Out:
# Platforms              3.934010
# Tracks                 4.792746
# Year of Opening     1914.542169
# dtype: float64

# %%
df.corr(numeric_only=True)
# Out:
#                   Platforms    Tracks  Year of Opening
# Platforms          1.000000  0.864724         -0.369114
# Tracks             0.864724  1.000000         -0.300378
# Year of Opening   -0.369114 -0.300378          1.000000

# %%
df.cov(numeric_only=True)
# Out:
#                   Platforms     Tracks  Year of Opening
# Platforms          6.276235   5.926706        -58.554351
# Tracks             5.926706   7.383905        -45.441734
# Year of Opening  -58.554351 -45.441734       2787.982956

# %%
df.Platforms.mean()
# Out:
# np.float64(3.934010152284264)

# %%
df.Tracks.sum()
# Out:
# np.float64(925.0)

# %%
df.fillna(0)
# Out:
#             Station Station Code            Line  \
# 0        Churchgate          CCG         Western
# 1      Marine Lines          MEL         Western
# 2       Charni Road          CYR         Western
# 3        Grant Road          GTR         Western
# 4    Mumbai Central         MMCT         Western
# ..              ...          ...             ...
# 197           Neral          NRL  Neral-Matheran
# 198       Jumapatti          JTT  Neral-Matheran
# 199       Waterpipe          WTP  Neral-Matheran
# 200      Aman Lodge         AMNA  Neral-Matheran
# 201        Matheran          MAE  Neral-Matheran
#
#     Distance From Previous of the Line Time taken From Previous of the Line  \
# 0                                 0 KM                                0 min
# 1                                 1 KM                                3 min
# 2                                 1 KM                                2 min
# ...

# %%
df.isnull()
# Out:
#      Station  Station Code   Line  Distance From Previous of the Line  \
# 0      False         False  False                               False
# 1      False         False  False                               False
# 2      False         False  False                               False
# 3      False         False  False                               False
# 4      False         False  False                               False
# ..       ...           ...    ...                                 ...
# 197    False         False  False                               False
# 198    False         False  False                               False
# 199    False         False  False                               False
# 200    False         False  False                               False
# 201    False         False  False                               False
#
#      Time taken From Previous of the Line  About  Platforms  Tracks  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Station                               202 non-null    object
#  1   Station Code                          202 non-null    object
#  2   Line                                  202 non-null    object
#  3   Distance From Previous of the Line    202 non-null    object
#  4   Time taken From Previous of the Line  202 non-null    object
#  5   About                                 202 non-null    object
#  6   Platforms                             197 non-null    float64
#  7   Tracks                                193 non-null    float64
#  8   Year of Opening                       83 non-null     float64
#  9   Nearby attractions                    202 non-null    object
#  10  Number of Passengers                  21 non-null     object
# ...

# %%
df[df.isnull()]
# Out:
#     Station Station Code Line Distance From Previous of the Line  \
# 0       NaN          NaN  NaN                                NaN
# 1       NaN          NaN  NaN                                NaN
# 2       NaN          NaN  NaN                                NaN
# 3       NaN          NaN  NaN                                NaN
# 4       NaN          NaN  NaN                                NaN
# ..      ...          ...  ...                                ...
# 197     NaN          NaN  NaN                                NaN
# 198     NaN          NaN  NaN                                NaN
# 199     NaN          NaN  NaN                                NaN
# 200     NaN          NaN  NaN                                NaN
# 201     NaN          NaN  NaN                                NaN
#
#     Time taken From Previous of the Line About  Platforms  Tracks  \
# 0                                    NaN   NaN        NaN     NaN
# ...

# %%
df1=df.drop(['Tracks'],axis=1)
df1
# Out:
#             Station Station Code            Line  \
# 0        Churchgate          CCG         Western
# 1      Marine Lines          MEL         Western
# 2       Charni Road          CYR         Western
# 3        Grant Road          GTR         Western
# 4    Mumbai Central         MMCT         Western
# ..              ...          ...             ...
# 197           Neral          NRL  Neral-Matheran
# 198       Jumapatti          JTT  Neral-Matheran
# 199       Waterpipe          WTP  Neral-Matheran
# 200      Aman Lodge         AMNA  Neral-Matheran
# 201        Matheran          MAE  Neral-Matheran
#
#     Distance From Previous of the Line Time taken From Previous of the Line  \
# 0                                 0 KM                                0 min
# 1                                 1 KM                                3 min
# 2                                 1 KM                                2 min
# ...

# %%
df1.drop(['Station','Line'],axis=1)
# Out:
#     Station Code Distance From Previous of the Line  \
# 0            CCG                               0 KM
# 1            MEL                               1 KM
# 2            CYR                               1 KM
# 3            GTR                               1 KM
# 4           MMCT                               1 KM
# ..           ...                                ...
# 197          NRL                               0 KM
# 198          JTT                               5 KM
# 199          WTP                               6 KM
# 200         AMNA                               7 KM
# 201          MAE                               2 KM
#
#     Time taken From Previous of the Line  \
# 0                                  0 min
# 1                                  3 min
# 2                                  2 min
# 3                                  3 min
# 4                                  2 min
# ..                                   ...
# 197                                0 min
# ...

# %%
del df['Line']

# %%
df
# Out:
#             Station Station Code Distance From Previous of the Line  \
# 0        Churchgate          CCG                               0 KM
# 1      Marine Lines          MEL                               1 KM
# 2       Charni Road          CYR                               1 KM
# 3        Grant Road          GTR                               1 KM
# 4    Mumbai Central         MMCT                               1 KM
# ..              ...          ...                                ...
# 197           Neral          NRL                               0 KM
# 198       Jumapatti          JTT                               5 KM
# 199       Waterpipe          WTP                               6 KM
# 200      Aman Lodge         AMNA                               7 KM
# 201        Matheran          MAE                               2 KM
#
#     Time taken From Previous of the Line  \
# 0                                  0 min
# 1                                  3 min
# ...

# %%
df.T
# Out:
#                                                                                     0    \
# Station                                                                      Churchgate
# Station Code                                                                        CCG
# Distance From Previous of the Line                                                 0 KM
# Time taken From Previous of the Line                                              0 min
# About                                 The Fort area built by the British had three m...
# Platforms                                                                           4.0
# Tracks                                                                              4.0
# Year of Opening                                                                  1867.0
# Nearby attractions                            Marine Drive,Nariman Point,Flora Fountain
# Number of Passengers                                                                NaN
# ...

# %%
df.transpose()
# Out:
#                                                                                     0    \
# Station                                                                      Churchgate
# Station Code                                                                        CCG
# Distance From Previous of the Line                                                 0 KM
# Time taken From Previous of the Line                                              0 min
# About                                 The Fort area built by the British had three m...
# Platforms                                                                           4.0
# Tracks                                                                              4.0
# Year of Opening                                                                  1867.0
# Nearby attractions                            Marine Drive,Nariman Point,Flora Fountain
# Number of Passengers                                                                NaN
# ...

# %%
df['new']=12
df
# Out:
#             Station Station Code Distance From Previous of the Line  \
# 0        Churchgate          CCG                               0 KM
# 1      Marine Lines          MEL                               1 KM
# 2       Charni Road          CYR                               1 KM
# 3        Grant Road          GTR                               1 KM
# 4    Mumbai Central         MMCT                               1 KM
# ..              ...          ...                                ...
# 197           Neral          NRL                               0 KM
# 198       Jumapatti          JTT                               5 KM
# 199       Waterpipe          WTP                               6 KM
# 200      Aman Lodge         AMNA                               7 KM
# 201        Matheran          MAE                               2 KM
#
#     Time taken From Previous of the Line  \
# 0                                  0 min
# 1                                  3 min
# ...

# %%
df['new'] = [3.0, 1.3, 2.2, 0.8, 1.1] * (len(df) // 5) + [3.0, 1.3, 2.2, 0.8, 1.1][:len(df) % 5]
df
# Out:
#             Station Station Code Distance From Previous of the Line  \
# 0        Churchgate          CCG                               0 KM
# 1      Marine Lines          MEL                               1 KM
# 2       Charni Road          CYR                               1 KM
# 3        Grant Road          GTR                               1 KM
# 4    Mumbai Central         MMCT                               1 KM
# ..              ...          ...                                ...
# 197           Neral          NRL                               0 KM
# 198       Jumapatti          JTT                               5 KM
# 199       Waterpipe          WTP                               6 KM
# 200      Aman Lodge         AMNA                               7 KM
# 201        Matheran          MAE                               2 KM
#
#     Time taken From Previous of the Line  \
# 0                                  0 min
# 1                                  3 min
# ...
